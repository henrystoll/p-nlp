# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("esg.csv")

# %%
df
# Out:
#     Ticker                           Name                Industry  \
# 0      MMM               3M Company (MMM)             Industrials
# 1      AOS  A. O. Smith Corporation (AOS)             Industrials
# 2      ABT      Abbott Laboratories (ABT)             Health Care
# 3     ABBV             AbbVie Inc. (ABBV)             Health Care
# 4     ABMD           Abiomed, Inc. (ABMD)             Health Care
# ..     ...                            ...                     ...
# 500    NaN                            NaN  Consumer Discretionary
# 501    NaN                            NaN  Information Technology
# 502    NaN                            NaN             Health Care
# 503    NaN                            NaN              Financials
# 504    NaN                            NaN             Health Care
#
#      Total ESG Risk Score  Environment Risk Score  Social Risk Score  \
# 0                    34.0                    12.6               12.6
# 1                    32.0                     9.5               14.9
# 2                    31.0                     3.7               15.9
# 3                    30.0                     1.0               16.5
# 4                     NaN                     NaN                NaN
# ..                    ...                     ...                ...
# 500                   NaN                     NaN                NaN
# 501                   NaN                     NaN                NaN
# 502                   NaN                     NaN                NaN
# 503                   NaN                     NaN                NaN
# 504                   NaN                     NaN                NaN
#
#      Governance Risk Score
# 0                      8.4
# 1                      7.6
# 2                     11.6
# 3                     12.8
# 4                      NaN
# ..                     ...
# 500                    NaN
# 501                    NaN
# 502                    NaN
# 503                    NaN
# 504                    NaN
#
# [505 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Ticker                    122
# Name                      122
# Industry                    0
# Total ESG Risk Score      149
# Environment Risk Score    149
# Social Risk Score         149
# Governance Risk Score     149
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#     Ticker                            Name                Industry  \
# 0      MMM                3M Company (MMM)             Industrials
# 1      AOS   A. O. Smith Corporation (AOS)             Industrials
# 2      ABT       Abbott Laboratories (ABT)             Health Care
# 3     ABBV              AbbVie Inc. (ABBV)             Health Care
# 5      ACN             Accenture plc (ACN)  Information Technology
# ..     ...                             ...                     ...
# 420   SBUX    Starbucks Corporation (SBUX)  Consumer Discretionary
# 421    STT  State Street Corporation (STT)              Financials
# 423    SYK       Stryker Corporation (SYK)             Health Care
# 426   SNPS           Synopsys, Inc. (SNPS)  Information Technology
# 427    SYY         Sysco Corporation (SYY)        Consumer Staples
#
#      Total ESG Risk Score  Environment Risk Score  Social Risk Score  \
# 0                    34.0                    12.6               12.6
# 1                    32.0                     9.5               14.9
# 2                    31.0                     3.7               15.9
# 3                    30.0                     1.0               16.5
# 5                    15.0                     1.0                8.2
# ..                    ...                     ...                ...
# 420                  21.0                     3.0               13.0
# 421                  22.0                     2.0               11.0
# 423                  37.0                     4.0               20.0
# 426                  20.0                     1.0               13.0
# 427                  13.0                     2.0                6.0
#
#      Governance Risk Score
# 0                      8.4
# 1                      7.6
# 2                     11.6
# 3                     12.8
# 5                      6.3
# ..                     ...
# 420                    5.0
# 421                    8.0
# 423                   12.0
# 426                    6.0
# 427                    5.0
#
# [356 rows x 7 columns]

# %%
df.describe()
# Out:
#        Total ESG Risk Score  Environment Risk Score  Social Risk Score  \
# count            356.000000              356.000000         356.000000
# mean              24.525281                6.489607          10.800843
# std                8.190474                7.594667           4.994580
# min               10.000000                0.000000           1.000000
# 25%               19.000000                1.000000           8.000000
# 50%               23.000000                4.000000          10.000000
# 75%               30.000000               10.000000          13.000000
# max               63.000000               76.000000          53.000000
#
#        Governance Risk Score
# count             356.000000
# mean                7.842416
# std                 4.716984
# min                 3.000000
# 25%                 6.000000
# 50%                 7.000000
# 75%                 9.000000
# max                67.000000

# %%
print(df[df["Total ESG Risk Score"]==max(df["Total ESG Risk Score"])]["Name"])
# Out:
# 104    Cigna Corporation (CI)
# Name: Name, dtype: object

# %%
sns.displot(df, x="Total ESG Risk Score")

# %%
bin_labels = ['negligent', 'low', 'medium', 'high','severe']
df['ESG Risk'] = pd.cut(df['Total ESG Risk Score'],
                              bins = [0,10,20,30,40,100],
                              labels=bin_labels)
df.head()
# Out:
# <ipython-input-59-e624d67ddc32>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ESG Risk'] = pd.cut(df['Total ESG Risk Score'],
#   Ticker                           Name                Industry  \
# 0    MMM               3M Company (MMM)             Industrials
# 1    AOS  A. O. Smith Corporation (AOS)             Industrials
# 2    ABT      Abbott Laboratories (ABT)             Health Care
# 3   ABBV             AbbVie Inc. (ABBV)             Health Care
# 5    ACN            Accenture plc (ACN)  Information Technology
#
#   Total ESG Risk Score Environment Risk Score Social Risk Score  \
# 0                 34.0                   12.6              12.6
# 1                 32.0                    9.5              14.9
# 2                 31.0                    3.7              15.9
# 3                 30.0                    1.0              16.5
# 5                 15.0                    1.0               8.2
#
#   Governance Risk Score        Performance ESG Risk
# 0                   8.4  Q2 — satisfactory     high
# 1                   7.6  Q2 — satisfactory     high
# 2                  11.6  Q2 — satisfactory     high
# 3                  12.8  Q2 — satisfactory   medium
# 5                   6.3          Q1 - poor      low
